# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline
from sklearn.linear_model import LogisticRegression
from mlxtend.plotting import plot_decision_regions
import missingno as msno

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/Machine Learning/Movies1.csv')
df
# Out:
#        Unnamed: 0  ...  rating
# 0               0  ...     9.2
# 1               1  ...     8.9
# 2               2  ...     8.4
# 3               3  ...     5.4
# 4               4  ...     8.2
# ...           ...  ...     ...
# 50008       50008  ...    10.0
# 50009       50009  ...     9.0
# 50010       50010  ...     9.2
# 50011       50011  ...     9.5
# 50012       50012  ...     8.9
#
# [50013 rows x 7 columns]

# %% [markdown]
# # ***Imputation***

# %%
df.dtypes                 # data type of each column
# Out:
# Unnamed: 0      int64
# userId        float64
# movieId       float64
# title          object
# genres         object
# review         object
# rating        float64
# dtype: object

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)  # dropped column named unknown

# %%
df.isnull().sum()
# Out:
# userId        1
# movieId       1
# title         1
# genres     3759
# review      103
# rating        0
# dtype: int64

# %%
df.drop(50012,axis=0,inplace=True)  # dropped last row

# %%
df
# Out:
#        userId  ...  rating
# 0         1.0  ...     9.2
# 1         1.0  ...     8.9
# 2         1.0  ...     8.4
# 3         1.0  ...     5.4
# 4         1.0  ...     8.2
# ...       ...  ...     ...
# 50007   397.0  ...     6.1
# 50008   302.0  ...    10.0
# 50009   186.0  ...     9.0
# 50010    18.0  ...     9.2
# 50011    24.0  ...     9.5
#
# [50012 rows x 6 columns]

# %%
df.isnull().sum() # count of null value in each column
# Out:
# userId        0
# movieId       0
# title         0
# genres     3758
# review      103
# rating        0
# dtype: int64

# %%
df.dtypes
# Out:
# userId     float64
# movieId    float64
# title       object
# genres      object
# review      object
# rating     float64
# dtype: object

# %%
df['userId']=df['userId'].astype(int)     # changing datatype to int from float

# %%
df['movieId']=df['movieId'].astype(int)   # changing datatype to int from float

# %%
df
# Out:
#        userId  ...  rating
# 0           1  ...     9.2
# 1           1  ...     8.9
# 2           1  ...     8.4
# 3           1  ...     5.4
# 4           1  ...     8.2
# ...       ...  ...     ...
# 50007     397  ...     6.1
# 50008     302  ...    10.0
# 50009     186  ...     9.0
# 50010      18  ...     9.2
# 50011      24  ...     9.5
#
# [50012 rows x 6 columns]

# %%
df.loc[df['genres'].isnull()==True,'movieId'] # checking null values in column genres
# Out:
# 15881     83773
# 16060     84768
# 16351     86493
# 16491     87061
# 17404     91246
#           ...
# 49968    179995
# 49972    180003
# 49973    180005
# 49993    180049
# 49995    180053
# Name: movieId, Length: 3758, dtype: int64

# %%
df['genres'].fillna('All',inplace=True)     # filling nan values

# %%
df['review'].fillna('Good',inplace=True)    # filling nan values

# %%
df.isnull().sum()       # final count of null values
# Out:
# userId     0
# movieId    0
# title      0
# genres     0
# review     0
# rating     0
# dtype: int64

# %% [markdown]
# # Preprocessing

# %%
df.describe()         # dataframe description excluding categorical data
# Out:
#              userId        movieId        rating
# count  50012.000000   50012.000000  50012.000000
# mean     195.318943  104437.677777      6.627409
# std      116.375446   58237.662083      2.794826
# min        1.000000       1.000000      1.000000
# 25%       92.000000   60467.500000      4.300000
# 50%      187.000000  122759.000000      7.500000
# 75%      294.000000  152784.000000      9.000000
# max      406.000000  180061.000000     10.000000

# %%
df2=df[['movieId','title','review','rating',"genres"]]      # creating new dataframe by copying column values

# %%
df2
# Out:
#        movieId  ...                                       genres
# 0            1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1            2  ...                   Adventure|Children|Fantasy
# 2            3  ...                               Comedy|Romance
# 3            4  ...                         Comedy|Drama|Romance
# 4            5  ...                                       Comedy
# ...        ...  ...                                          ...
# 50007   120641  ...                       Action|Romance|Western
# 50008   120729  ...                               Comedy|Romance
# 50009   120731  ...                                    Adventure
# 50010   120733  ...                                       Comedy
# 50011   120735  ...                                Drama|Romance
#
# [50012 rows x 5 columns]

# %% [markdown]
# **Creating** a new column called sentiment based on ratings

# %%
for i in range(len(df2)):
  if df2.iloc[i]['rating']>=8.0:
    df2.at[i,'sentiment']="GOOD"
  elif df2.iloc[i]['rating']<8 and df2.iloc[i]['rating']>=6:
    df2.at[i,'sentiment']="ABOVE AVERAGE"
  elif df2.iloc[i]['rating']<6 and df2.iloc[i]['rating']>=5:
    df2.at[i,'sentiment']="BELOW AVERAGE"
  else:
    df2.at[i,'sentiment']="BAD"

# %%
df2 # after creating new column
# Out:
#        movieId  ...      sentiment
# 0            1  ...           GOOD
# 1            2  ...           GOOD
# 2            3  ...           GOOD
# 3            4  ...  BELOW AVERAGE
# 4            5  ...           GOOD
# ...        ...  ...            ...
# 50007   120641  ...  ABOVE AVERAGE
# 50008   120729  ...           GOOD
# 50009   120731  ...           GOOD
# 50010   120733  ...           GOOD
# 50011   120735  ...           GOOD
#
# [50012 rows x 6 columns]

# %%
lb_make = LabelEncoder()              # label encoding the categorical data sentiment
df2['sent_code'] = lb_make.fit_transform(df2['sentiment'])

# %%
df2.head(10)            #final dataframe after preprocessing
# Out:
#    movieId                               title  ...      sentiment  sent_code
# 0        1                    Toy Story (1995)  ...           GOOD          3
# 1        2                      Jumanji (1995)  ...           GOOD          3
# 2        3             Grumpier Old Men (1995)  ...           GOOD          3
# 3        4            Waiting to Exhale (1995)  ...  BELOW AVERAGE          2
# 4        5  Father of the Bride Part II (1995)  ...           GOOD          3
# 5        6                         Heat (1995)  ...           GOOD          3
# 6        7                      Sabrina (1995)  ...           GOOD          3
# 7        8                 Tom and Huck (1995)  ...  ABOVE AVERAGE          0
# 8        9                 Sudden Death (1995)  ...            BAD          1
# 9       10                    GoldenEye (1995)  ...           GOOD          3
#
# [10 rows x 7 columns]

# %%
df2.dtypes
# Out:
# movieId        int64
# title         object
# review        object
# rating       float64
# genres        object
# sentiment     object
# sent_code      int64
# dtype: object

# %%
df2['title']=df2['title'].astype(str)

# %%
df.dtypes
# Out:
# userId       int64
# movieId      int64
# title       object
# genres      object
# review      object
# rating     float64
# dtype: object

# %%
from scipy import stats        # z score calculation
l=df2['rating']
print(stats.zscore(l))
# Out:
# [0.92049263 0.81315033 0.6342465  ... 0.8489311  0.92049263 1.02783493]

# %%
print(df2.sentiment.value_counts())
df4=df2.sentiment.value_counts().plot(kind="bar",color=['green','red'])
# Out:
# GOOD             24992
# BAD              14210
# ABOVE AVERAGE     7172
# BELOW AVERAGE     3638
# Name: sentiment, dtype: int64

# %%
df3 =df2.corr(method='pearson')
print(df3)
sns.heatmap(df3,xticklabels="auto",yticklabels="auto")
# Out:
#             movieId    rating  sent_code
# movieId    1.000000  0.005463  -0.000127
# rating     0.005463  1.000000   0.693416
# sent_code -0.000127  0.693416   1.000000

# %%
print('Minimum Rating Value=',np.amin(df2['rating']))
print('Maximum Rating Value=',np.amax(df2['rating']))
# Out:
# Minimum Rating Value= 1.0
# Maximum Rating Value= 10.0

# %%
plt.subplots(figsize = (10,12))
plt.subplot(3,1,1)
sns.boxplot(x=df2['rating'])

# %%
threshold = 3             #outlier using z-score
outlier = []
mean=np.mean(df2['rating'])
std=np.std(df2['rating'])
for i in df2['rating']:
    z = (i-mean)/std
    if z > threshold:
        outlier.append(i)
print('outlier in dataset is', outlier)
# Out:
# outlier in dataset is []

# %%
#Detecting the repeatedly used positive words 
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

positive_data = df2[(df2.sent_code == 0) | (df2.sent_code ==3)]['review']
positive_data_string = ' '.join(positive_data)
plt.figure(figsize = (20,20))
wc = WordCloud(max_words = 2000, width=1200, height=600,background_color="white").generate(positive_data_string)
plt.imshow(wc , interpolation = 'bilinear')
plt.axis('off')
plt.title('Positive reviews',fontsize = 20)
plt.show()

# %%
#3Nithin

# %%
#Detecting the repeatedly used negative words
negative_data = df2[df2.sent_code == 0]['review']
positive_data = df2[(df2.sent_code == 1) | (df2.sent_code ==2)]['review']
negative_data_string = ' '.join(negative_data)
plt.figure(figsize = (20,20))
wc = WordCloud(max_words = 2000, width=1200, height=600,background_color="white").generate(negative_data_string)
plt.imshow(wc , interpolation = 'bilinear')
plt.axis('off')
plt.title('Negative reviews',fontsize = 20)
plt.show()

# %%
df=df2

# %%
#x=input("Enter a genere you would like to search")
x="Comedy"
a=[]
for i in df.index:
  #print(df.iloc[i,4])
  s=df.iloc[i,4]
  l=s.split('|')
  #rint(l,df.iloc[i,6])
  
  if (l[0]=="All" or x in l) and (df.iloc[i,6]==0 or df.iloc[i,6]==3):
    a.append(df.iloc[i,1])
    if len(a)==5:
      break
#print(df.iloc[0,5])
print("The recommended movies for your searched genre is:\n")
print(a)
# Out:
# The recommended movies for your searched genre is:
#
# ['Toy Story (1995)', 'Grumpier Old Men (1995)', 'Father of the Bride Part II (1995)', 'Sabrina (1995)', 'Dracula: Dead and Loving It (1995)']

# %%
 x="film show br movie is Penitentary."
#print(positive_data_string)
l=x.split()
a=positive_data_string.split()
b=negative_data_string.split()
count=0
for i in l:
  if i in a:
    count+=1;
  if i in b:
    count-=1;

if count>=1:
  print("The review is positive")
elif count<0:

  print("The review is negative")
else :
  print("Neither positive nor negative review")
# Out:
# The review is positive

# %% [markdown]
# # Review 2

# %%
df
# Out:
#        movieId                                 title  ...      sentiment  sent_code
# 0            1                      Toy Story (1995)  ...           GOOD          3
# 1            2                        Jumanji (1995)  ...           GOOD          3
# 2            3               Grumpier Old Men (1995)  ...           GOOD          3
# 3            4              Waiting to Exhale (1995)  ...  BELOW AVERAGE          2
# 4            5    Father of the Bride Part II (1995)  ...           GOOD          3
# ...        ...                                   ...  ...            ...        ...
# 50007   120641                       Santa Fe (1951)  ...  ABOVE AVERAGE          0
# 50008   120729    Mexican Spitfire's Elephant (1942)  ...           GOOD          3
# 50009   120731           Revolt of the Slaves (1960)  ...           GOOD          3
# 50010   120733  Mexican Spitfire Sees a Ghost (1942)  ...           GOOD          3
# 50011   120735                Love Chronicles (2003)  ...           GOOD          3
#
# [50012 rows x 7 columns]

# %%
cols=[]
for i in df.columns:
  cols.append(i)
cols
# Out:
# ['movieId', 'title', 'review', 'rating', 'genres', 'sentiment', 'sent_code']

# %%
from sklearn.model_selection import train_test_split

x=df.drop(['sent_code','title','review','genres','sentiment'], axis = 1)
#x["sentiment"]=y
y= df['sent_code']
print(x.shape, y.shape)
x.reset_index(drop=True,inplace=True,)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.5, random_state = 0)
# Out:
# (50012, 2) (50012,)

# %%
x_train
# Out:
#        movieId  rating
# 23339   117712     3.4
# 42730   164503     9.4
# 40554   159712     8.9
# 46275   172115     8.6
# 39172   156587     5.0
# ...        ...     ...
# 21243   109684     9.2
# 45891   171325     9.0
# 42613   164236     9.0
# 43567   166338     4.1
# 2732      2824     9.6
#
# [25006 rows x 2 columns]

# %%
#Finding optimal graph for n estimators
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
scores =[]
for k in range(1, 100):
    rfc = RandomForestClassifier(n_estimators=k)
    rfc.fit(x_train, y_train)
    y_pred = rfc.predict(x_test)
    scores.append(accuracy_score(y_test, y_pred))

import matplotlib.pyplot as plt
# %matplotlib inline

# plot the relationship between K and testing accuracy
# plt.plot(x_axis, y_axis)
plt.plot(range(1, 100), scores)
plt.xlabel('Value of n_estimators for Random Forest Classifier')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
clf= RandomForestClassifier(n_estimators= 10, criterion="entropy")  
clf.fit(x_train, y_train) 
y_pred= clf.predict(x_test)
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3599
#            1       1.00      1.00      1.00      7100
#            2       1.00      1.00      1.00      1838
#            3       1.00      1.00      1.00     12469
#
#     accuracy                           1.00     25006
#    macro avg       1.00      1.00      1.00     25006
# weighted avg       1.00      1.00      1.00     25006

# %%
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.under_sampling import NearMiss
from matplotlib import pyplot
from numpy import where
# define dataset
X, y =x_train,y_train
# summarize class distribution
counter = Counter(y)
print(counter)
# define the undersampling method
undersample = NearMiss(version=1, n_neighbors=3)
# transform the dataset
x_train, y_train = undersample.fit_resample(X, y)
y
# Out:
# Counter({3: 12523, 1: 7110, 0: 3573, 2: 1800})
# 23339    1
# 42730    3
# 40554    3
# 46275    3
# 39172    2
#         ..
# 21243    3
# 45891    3
# 42613    3
# 43567    1
# 2732     3
# Name: sent_code, Length: 25006, dtype: int64

# %%
#Finding optimal graph for n estimators
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
scores =[]
for k in range(1, 100):
    rfc = RandomForestClassifier(n_estimators=k)
    rfc.fit(x_train, y_train)
    y_pred = rfc.predict(x_test)
    scores.append(accuracy_score(y_test, y_pred))

import matplotlib.pyplot as plt
# %matplotlib inline

# plot the relationship between K and testing accuracy
# plt.plot(x_axis, y_axis)
plt.plot(range(1, 100), scores)
plt.xlabel('Value of n_estimators for Random Forest Classifier')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
clf= RandomForestClassifier(n_estimators= 10, criterion="entropy")  
clf.fit(x_train, y_train) 
y_pred= clf.predict(x_test)
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3599
#            1       1.00      1.00      1.00      7100
#            2       1.00      1.00      1.00      1838
#            3       1.00      1.00      1.00     12469
#
#     accuracy                           1.00     25006
#    macro avg       1.00      1.00      1.00     25006
# weighted avg       1.00      1.00      1.00     25006

# %% [markdown]
# ***SVM***

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
x_train = sc_X.fit_transform(x_train)
x_test = sc_X.transform(x_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# SVC(random_state=0)

# %%
Y_Pred = classifier.predict(x_test)

# %%
classifier.score(x_train,y_train)
# Out:
# 1.0

# %%
classifier.score(x_test,y_test)
# Out:
# 1.0

# %%
accuracy_score(y_test, Y_Pred)
# Out:
# 1.0

# %%
cm = confusion_matrix(y_test, Y_Pred)

# %%
print(confusion_matrix(y_test, Y_Pred))
# Out:
# [[ 3599     0     0     0]
#  [    0  7100     0     0]
#  [    0     0  1838     0]
#  [    0     0     0 12469]]

# %%
print(classification_report(y_test, Y_Pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3599
#            1       1.00      1.00      1.00      7100
#            2       1.00      1.00      1.00      1838
#            3       1.00      1.00      1.00     12469
#
#     accuracy                           1.00     25006
#    macro avg       1.00      1.00      1.00     25006
# weighted avg       1.00      1.00      1.00     25006
